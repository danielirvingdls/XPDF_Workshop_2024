# %% [markdown]
# # SAPA for ScF3 - Single Mode Refinement
#
# In this example, we will run SAPA for X-ray PDF data for ScF3, refining each mode on its own. It is recommended to use the Grouped Mode tutorial first, as that goes into more depth on the steps of the tutorial. In this tutorial, I will mainly highlight the differences of this method of operation from the Grouped Mode method.
#
# ScF3 is a formed from corner-sharing ScF6 octahedra, so shares a lot of similarities to the perovskite structure, such that the mode listing for ScF3 is a subset of those found for the ABX3 perovskite.
#
# As with the grouped mode tutorial, we have to tell the Python interpreter where to look for the SAPA scripts:

# %%
import sys
sys.path.append('..')

# %% [markdown]
# And then import the sapa script and create the sapa object:

# %%
import sapa as s

struc = s.sapa('ScF3_iso.cif')

# %% [markdown]
# Writing the input file for the Single Mode version requires an extra argument, as it writes the mode definitions out differently, but otherwise is exactly the same as the Grouped Mode version. The filename has been specified here, so we don't overwrite the grouped mode input file, and the cycles have been reduced significantly, as we are only refining one mode.

# %%
struc.write_inp(sample = 'ScF3_20',
               filenameformat = 'ScF3_##n##K_dofr.xye',
               isneutron = False,
               qmax = 21.0,
               dq = 0.08,
               startx = 1.0,
               finishx = 20.0,
               lattice = 'C',
               singlemode = True,
                cycles = 10,
               filename = 'ScF3_20_modes_single.inp')
# Out:
# Creating input file...
# 96
# 96
# ...ScF3_20_modes_single.inp written

# %% [markdown]
# The execution uses a different function, but only has one argument different from the grouped mode version. This is the 'unique_modes' argument. If this is specified, the script looks for which modes are effectively equivalent - i.e the same irrep, wyckoff position (w.r.t the input unit cell) and character, and then the script only executes one of those modes. This drastically reduces the number of modes that need to be executed. 'unique_modes' is set to True by default.
#
# As before, we still need to define temperatures;

# %%
temps = ['125', '140', '147', '152', '175', '200', '225', '250', '275', '325', '350', '375', '400']
#print(struc.filename)

struc.execute_single(temps, verbose=True)
# Out:
# Finding Topas executables...
# Creating Monitoring File...
# Executing only unique modes for each irrep...
# Executing mode 0 , irrep nomodes for temp 125
# Completed mode 0 (irrep nomodes) for temp 125. Process took 4.531177282333374s (0.0755196213722229 minutes)
# Estimated 0.44053112467130023 hours to completion.
# Executing mode 1 , irrep GM4- for temp 125
# Completed mode 1 (irrep GM4-) for temp 125. Process took 5.468914985656738s (0.09114858309427896 minutes)
# Estimated 0.48472669465674295 hours to completion.
# Executing mode 25 , irrep GM4- for temp 125
# Completed mode 25 (irrep GM4-) for temp 125. Process took 5.699998140335083s (0.09499996900558472 minutes)
# Estimated 0.5058918020460341 hours to completion.
# Executing mode 28 , irrep GM4- for temp 125
# Completed mode 28 (irrep GM4-) for temp 125. Process took 4.9078028202056885s (0.0817967136700948 minutes)
# Estimated 0.4965929826597373 hours to completion.
# Executing mode 4 , irrep R5+ for temp 125
# Completed mode 4 (irrep R5+) for temp 125. Process took 6.001725435256958s (0.10002875725428263 minutes)
# Estimated 0.5114960032039219 hours to completion.
# Executing mode 7 , irrep X1+ for temp 125
# Completed mode 7 (irrep X1+) for temp 125. Process took 5.640915155410767s (0.09401525259017944 minutes)
# Estimated 0.5151126929455333 hours to completion.
# Executing mode 43 , irrep X1+ for temp 125
# Completed mode 43 (irrep X1+) for temp 125. Process took 4.776560306549072s (0.07960933844248454 minutes)
# Estimated 0.5054492213990953 hours to completion.
# Executing mode 10 , irrep X5+ for temp 125
# Completed mode 10 (irrep X5+) for temp 125. Process took 5.540405035018921s (0.09234008391698202 minutes)
# Estimated 0.5069670906994078 hours to completion.
# Executing mode 49 , irrep X5+ for temp 125
# Completed mode 49 (irrep X5+) for temp 125. Process took 6.758366107940674s (0.11263943513234456 minutes)
# Estimated 0.5206619111696879 hours to completion.
# Executing mode 55 , irrep X5+ for temp 125
# Completed mode 55 (irrep X5+) for temp 125. Process took 4.7364821434021s (0.07894136905670165 minutes)
# Estimated 0.5120905685424805 hours to completion.
# Executing mode 16 , irrep M2- for temp 125
# Completed mode 16 (irrep M2-) for temp 125. Process took 5.843937158584595s (0.09739895264307658 minutes)
# Estimated 0.5143468877281806 hours to completion.
# Executing mode 88 , irrep M2- for temp 125
# Completed mode 88 (irrep M2-) for temp 125. Process took 9.774065017700195s (0.16290108362833658 minutes)
# Estimated 0.5467971877422597 hours to completion.
# Executing mode 19 , irrep M5- for temp 125
# Completed mode 19 (irrep M5-) for temp 125. Process took 5.92448616027832s (0.09874143600463867 minutes)
# Estimated 0.5460349248515235 hours to completion.
# Executing mode 91 , irrep M5- for temp 125
# Completed mode 91 (irrep M5-) for temp 125. Process took 4.973519563674927s (0.08289199272791545 minutes)
# Estimated 0.5387878123067673 hours to completion.
# Executing mode 31 , irrep GM5- for temp 125
# Completed mode 31 (irrep GM5-) for temp 125. Process took 5.095022916793823s (0.08491704861323039 minutes)
# Estimated 0.5330787978702122 hours to completion.
# Executing mode 34 , irrep R2- for temp 125
# Completed mode 34 (irrep R2-) for temp 125. Process took 9.15439248085022s (0.15257320801417032 minutes)
# Estimated 0.5515156803445683 hours to completion.
# Executing mode 35 , irrep R3- for temp 125
# Completed mode 35 (irrep R3-) for temp 125. Process took 9.735355854034424s (0.16225593090057372 minutes)
# Estimated 0.5706549717709909 hours to completion.
# Executing mode 37 , irrep R4- for temp 125
# Completed mode 37 (irrep R4-) for temp 125. Process took 4.922006845474243s (0.08203344742457072 minutes)
# Estimated 0.5626319355765979 hours to completion.
# Executing mode 40 , irrep R5- for temp 125
# Completed mode 40 (irrep R5-) for temp 125. Process took 4.906339883804321s (0.08177233139673869 minutes)
# Estimated 0.555233466862238 hours to completion.
# Executing mode 46 , irrep X2+ for temp 125
# Completed mode 46 (irrep X2+) for temp 125. Process took 4.906313419342041s (0.08177189032236735 minutes)
# Estimated 0.5484384361373054 hours to completion.
# Executing mode 61 , irrep X3- for temp 125
# Completed mode 61 (irrep X3-) for temp 125. Process took 7.438630819320679s (0.12397718032201131 minutes)
# Estimated 0.5532145209728725 hours to completion.
# Executing mode 64 , irrep X5- for temp 125
# Completed mode 64 (irrep X5-) for temp 125. Process took 5.046937704086304s (0.0841156284014384 minutes)
# Estimated 0.5474333822305756 hours to completion.
# Executing mode 70 , irrep M1+ for temp 125
# Completed mode 70 (irrep M1+) for temp 125. Process took 5.10865044593811s (0.0851441740989685 minutes)
# Estimated 0.5422775104310777 hours to completion.
# Executing mode 73 , irrep M2+ for temp 125
# Completed mode 73 (irrep M2+) for temp 125. Process took 5.118787050247192s (0.08531311750411988 minutes)
# Estimated 0.5374714030490981 hours to completion.
# Executing mode 76 , irrep M3+ for temp 125
# Completed mode 76 (irrep M3+) for temp 125. Process took 7.646820068359375s (0.12744700113932292 minutes)
# Estimated 0.5420931308110555 hours to completion.
# Executing mode 79 , irrep M4+ for temp 125
# Completed mode 79 (irrep M4+) for temp 125. Process took 10.31288194656372s (0.171881365776062 minutes)
# Estimated 0.5554531067609787 hours to completion.
# Executing mode 82 , irrep M5+ for temp 125
# Completed mode 82 (irrep M5+) for temp 125. Process took 5.187547206878662s (0.08645912011464436 minutes)
# Estimated 0.5505268065134685 hours to completion.
# Executing mode 0 , irrep nomodes for temp 140
# Completed mode 0 (irrep nomodes) for temp 140. Process took 5.366722345352173s (0.08944537242253621 minutes)
# Estimated 0.546423599887935 hours to completion.
# Executing mode 1 , irrep GM4- for temp 140
# Completed mode 1 (irrep GM4-) for temp 140. Process took 6.23757529258728s (0.103959588209788 minutes)
# Estimated 0.5451865263277543 hours to completion.
# Executing mode 25 , irrep GM4- for temp 140
# Completed mode 25 (irrep GM4-) for temp 140. Process took 6.076154470443726s (0.1012692411740621 minutes)
# Estimated 0.5434366351299816 hours to completion.
# Executing mode 28 , irrep GM4- for temp 140
# Completed mode 28 (irrep GM4-) for temp 140. Process took 5.006458759307861s (0.08344097932179768 minutes)
# Estimated 0.5386235206357894 hours to completion.
# Executing mode 4 , irrep R5+ for temp 140
# Completed mode 4 (irrep R5+) for temp 140. Process took 5.546926736831665s (0.09244877894719442 minutes)
# Estimated 0.535520916485952 hours to completion.
# Executing mode 7 , irrep X1+ for temp 140
# Completed mode 7 (irrep X1+) for temp 140. Process took 6.578251123428345s (0.10963751872380574 minutes)
# Estimated 0.5352735821285634 hours to completion.
# Executing mode 43 , irrep X1+ for temp 140
# Completed mode 43 (irrep X1+) for temp 140. Process took 5.062574863433838s (0.0843762477238973 minutes)
# Estimated 0.5310079057017962 hours to completion.
# Executing mode 10 , irrep X5+ for temp 140
# Completed mode 10 (irrep X5+) for temp 140. Process took 7.031383752822876s (0.1171897292137146 minutes)
# Estimated 0.5318432715733846 hours to completion.
# Executing mode 49 , irrep X5+ for temp 140
# Completed mode 49 (irrep X5+) for temp 140. Process took 10.09390902519226s (0.16823181708653767 minutes)
# Estimated 0.5399673570361402 hours to completion.
# Executing mode 55 , irrep X5+ for temp 140
# Completed mode 55 (irrep X5+) for temp 140. Process took 4.534526348114014s (0.07557543913523355 minutes)
# Estimated 0.5343952908924035 hours to completion.
# Executing mode 16 , irrep M2- for temp 140
# Completed mode 16 (irrep M2-) for temp 140. Process took 6.668761491775513s (0.11114602486292521 minutes)
# Estimated 0.5339333521134673 hours to completion.
# Executing mode 88 , irrep M2- for temp 140
# Completed mode 88 (irrep M2-) for temp 140. Process took 7.469354629516602s (0.1244892438252767 minutes)
# Estimated 0.5351792017618816 hours to completion.
# Executing mode 19 , irrep M5- for temp 140
# Completed mode 19 (irrep M5-) for temp 140. Process took 6.718194484710693s (0.11196990807851155 minutes)
# Estimated 0.534636720634169 hours to completion.
# Executing mode 91 , irrep M5- for temp 140
# Completed mode 91 (irrep M5-) for temp 140. Process took 5.009449005126953s (0.08349081675211588 minutes)
# Estimated 0.5304408409731175 hours to completion.
# Executing mode 31 , irrep GM5- for temp 140
# Completed mode 31 (irrep GM5-) for temp 140. Process took 5.318921327590942s (0.08864868879318237 minutes)
# Estimated 0.527010955909888 hours to completion.
# Executing mode 34 , irrep R2- for temp 140
# Completed mode 34 (irrep R2-) for temp 140. Process took 10.624883651733398s (0.17708139419555663 minutes)
# Estimated 0.5342289631311283 hours to completion.
# Executing mode 35 , irrep R3- for temp 140
# Completed mode 35 (irrep R3-) for temp 140. Process took 12.686620235443115s (0.21144367059071859 minutes)
# Estimated 0.5449806427759956 hours to completion.
# Executing mode 37 , irrep R4- for temp 140
# Completed mode 37 (irrep R4-) for temp 140. Process took 5.297786235809326s (0.08829643726348876 minutes)
# Estimated 0.541141158607271 hours to completion.
# Executing mode 40 , irrep R5- for temp 140
# Completed mode 40 (irrep R5-) for temp 140. Process took 5.160499572753906s (0.0860083262125651 minutes)
# Estimated 0.5371517727556436 hours to completion.
# Executing mode 46 , irrep X2+ for temp 140
# Completed mode 46 (irrep X2+) for temp 140. Process took 5.089478254318237s (0.08482463757197062 minutes)
# Estimated 0.5331435458767217 hours to completion.
# Executing mode 61 , irrep X3- for temp 140
# Completed mode 61 (irrep X3-) for temp 140. Process took 8.506079196929932s (0.14176798661549886 minutes)
# Estimated 0.5352343373000622 hours to completion.
# Executing mode 64 , irrep X5- for temp 140
# Completed mode 64 (irrep X5-) for temp 140. Process took 5.025316476821899s (0.08375527461369832 minutes)
# Estimated 0.5311842205708259 hours to completion.
# Executing mode 70 , irrep M1+ for temp 140
# Completed mode 70 (irrep M1+) for temp 140. Process took 5.984391927719116s (0.09973986546198527 minutes)
# Estimated 0.5288440589427948 hours to completion.
# Executing mode 73 , irrep M2+ for temp 140
# Completed mode 73 (irrep M2+) for temp 140. Process took 5.241753816604614s (0.08736256361007691 minutes)
# Estimated 0.5253170179385765 hours to completion.
# Executing mode 76 , irrep M3+ for temp 140
# Completed mode 76 (irrep M3+) for temp 140. Process took 9.164387226104736s (0.1527397871017456 minutes)
# Estimated 0.5281349479655425 hours to completion.
# Executing mode 79 , irrep M4+ for temp 140
# Completed mode 79 (irrep M4+) for temp 140. Process took 8.281532764434814s (0.13802554607391357 minutes)
# Estimated 0.5293715965447936 hours to completion.
# Executing mode 82 , irrep M5+ for temp 140
# Completed mode 82 (irrep M5+) for temp 140. Process took 4.906666278839111s (0.08177777131398518 minutes)
# Estimated 0.5253211963507864 hours to completion.
# Executing mode 0 , irrep nomodes for temp 147
# Completed mode 0 (irrep nomodes) for temp 147. Process took 4.593289613723755s (0.07655482689539592 minutes)
# Estimated 0.5209000388636734 hours to completion.
# Executing mode 1 , irrep GM4- for temp 147
# Completed mode 1 (irrep GM4-) for temp 147. Process took 6.156191825866699s (0.10260319709777832 minutes)
# Estimated 0.5188781963927405 hours to completion.
# Executing mode 25 , irrep GM4- for temp 147
# Completed mode 25 (irrep GM4-) for temp 147. Process took 6.578185081481934s (0.1096364180246989 minutes)
# Estimated 0.5174719041132788 hours to completion.
# Executing mode 28 , irrep GM4- for temp 147
# Completed mode 28 (irrep GM4-) for temp 147. Process took 4.828221321105957s (0.08047035535176596 minutes)
# Estimated 0.5135954468551724 hours to completion.
# Executing mode 4 , irrep R5+ for temp 147
# Completed mode 4 (irrep R5+) for temp 147. Process took 5.674102067947388s (0.09456836779912313 minutes)
# Estimated 0.5109678183526867 hours to completion.
# Executing mode 7 , irrep X1+ for temp 147
# Completed mode 7 (irrep X1+) for temp 147. Process took 6.087424278259277s (0.10145707130432129 minutes)
# Estimated 0.5089320763515102 hours to completion.
# Executing mode 43 , irrep X1+ for temp 147
# Completed mode 43 (irrep X1+) for temp 147. Process took 4.972790718078613s (0.08287984530131022 minutes)
# Estimated 0.5054356729723717 hours to completion.
# Executing mode 10 , irrep X5+ for temp 147
# Completed mode 10 (irrep X5+) for temp 147. Process took 6.596808910369873s (0.10994681517283121 minutes)
# Estimated 0.5041102811544599 hours to completion.
# Executing mode 49 , irrep X5+ for temp 147
# Completed mode 49 (irrep X5+) for temp 147. Process took 8.485531330108643s (0.14142552216847737 minutes)
# Estimated 0.5051671700250534 hours to completion.
# Executing mode 55 , irrep X5+ for temp 147
# Completed mode 55 (irrep X5+) for temp 147. Process took 4.750423431396484s (0.07917372385660808 minutes)
# Estimated 0.5014646985247317 hours to completion.
# Executing mode 16 , irrep M2- for temp 147
# Completed mode 16 (irrep M2-) for temp 147. Process took 7.772593259811401s (0.1295432209968567 minutes)
# Estimated 0.501529310438368 hours to completion.
# Executing mode 88 , irrep M2- for temp 147
# Completed mode 88 (irrep M2-) for temp 147. Process took 8.816716432571411s (0.1469452738761902 minutes)
# Estimated 0.5027789590184134 hours to completion.
# Executing mode 19 , irrep M5- for temp 147
# Completed mode 19 (irrep M5-) for temp 147. Process took 7.3468239307403564s (0.12244706551233928 minutes)
# Estimated 0.5021874783564958 hours to completion.
# Executing mode 91 , irrep M5- for temp 147
# Completed mode 91 (irrep M5-) for temp 147. Process took 4.637573003768921s (0.07729288339614868 minutes)
# Estimated 0.4984213530890692 hours to completion.
# Executing mode 31 , irrep GM5- for temp 147
# Completed mode 31 (irrep GM5-) for temp 147. Process took 4.890681028366089s (0.08151135047276815 minutes)
# Estimated 0.4950143961745184 hours to completion.
# Executing mode 34 , irrep R2- for temp 147
# Completed mode 34 (irrep R2-) for temp 147. Process took 8.606244325637817s (0.14343740542729697 minutes)
# Estimated 0.495809113919735 hours to completion.
# Executing mode 35 , irrep R3- for temp 147
# Completed mode 35 (irrep R3-) for temp 147. Process took 10.16456937789917s (0.16940948963165284 minutes)
# Estimated 0.498221189091463 hours to completion.
# Executing mode 37 , irrep R4- for temp 147
# Completed mode 37 (irrep R4-) for temp 147. Process took 5.51041841506958s (0.09184030691782634 minutes)
# Estimated 0.49547815547221236 hours to completion.
# Executing mode 40 , irrep R5- for temp 147
# Completed mode 40 (irrep R5-) for temp 147. Process took 5.203044414520264s (0.08671740690867107 minutes)
# Estimated 0.49244318514472635 hours to completion.
# Executing mode 46 , irrep X2+ for temp 147
# Completed mode 46 (irrep X2+) for temp 147. Process took 5.703273057937622s (0.09505455096562704 minutes)
# Estimated 0.48997131178328945 hours to completion.
# Executing mode 61 , irrep X3- for temp 147
# Completed mode 61 (irrep X3-) for temp 147. Process took 7.736495018005371s (0.12894158363342284 minutes)
# Estimated 0.4896015132480197 hours to completion.
# Executing mode 64 , irrep X5- for temp 147
# Completed mode 64 (irrep X5-) for temp 147. Process took 4.357263803482056s (0.07262106339136759 minutes)
# Estimated 0.48578837032468 hours to completion.
# Executing mode 70 , irrep M1+ for temp 147
# Completed mode 70 (irrep M1+) for temp 147. Process took 5.093788385391235s (0.08489647308985392 minutes)
# Estimated 0.48277085451852714 hours to completion.
# Executing mode 73 , irrep M2+ for temp 147
# Completed mode 73 (irrep M2+) for temp 147. Process took 6.453165769577026s (0.10755276282628377 minutes)
# Estimated 0.4811160472697682 hours to completion.
# Executing mode 76 , irrep M3+ for temp 147
# Completed mode 76 (irrep M3+) for temp 147. Process took 7.7030229568481445s (0.12838371594746908 minutes)
# Estimated 0.4806531156735749 hours to completion.
# Executing mode 79 , irrep M4+ for temp 147
# Completed mode 79 (irrep M4+) for temp 147. Process took 7.422038316726685s (0.1237006386121114 minutes)
# Estimated 0.4798838654110829 hours to completion.
# Executing mode 82 , irrep M5+ for temp 147
# Completed mode 82 (irrep M5+) for temp 147. Process took 4.906301259994507s (0.08177168766657511 minutes)
# Estimated 0.4767533172059942 hours to completion.
# Executing mode 0 , irrep nomodes for temp 152
# Completed mode 0 (irrep nomodes) for temp 152. Process took 6.172849178314209s (0.10288081963857015 minutes)
# Estimated 0.47482002081182917 hours to completion.
# Executing mode 1 , irrep GM4- for temp 152
# Completed mode 1 (irrep GM4-) for temp 152. Process took 5.452091932296753s (0.09086819887161254 minutes)
# Estimated 0.47224552995229824 hours to completion.
# Executing mode 25 , irrep GM4- for temp 152
# Completed mode 25 (irrep GM4-) for temp 152. Process took 6.3285839557647705s (0.10547639926274617 minutes)
# Estimated 0.47047016449154366 hours to completion.
# Executing mode 28 , irrep GM4- for temp 152
# Completed mode 28 (irrep GM4-) for temp 152. Process took 4.999621391296387s (0.0833270231882731 minutes)
# Estimated 0.46753996707411366 hours to completion.
# Executing mode 4 , irrep R5+ for temp 152
# Completed mode 4 (irrep R5+) for temp 152. Process took 6.46867036819458s (0.107811172803243 minutes)
# Estimated 0.46590303889925777 hours to completion.
# Executing mode 7 , irrep X1+ for temp 152
# Completed mode 7 (irrep X1+) for temp 152. Process took 5.90630316734314s (0.09843838612238566 minutes)
# Estimated 0.4637884083013425 hours to completion.
# Executing mode 43 , irrep X1+ for temp 152
# Completed mode 43 (irrep X1+) for temp 152. Process took 5.141700029373169s (0.08569500048955282 minutes)
# Estimated 0.46104979446063743 hours to completion.
# Executing mode 10 , irrep X5+ for temp 152
# Completed mode 10 (irrep X5+) for temp 152. Process took 6.002135515213013s (0.10003559192021688 minutes)
# Estimated 0.4590442290496588 hours to completion.
# Executing mode 49 , irrep X5+ for temp 152
# Completed mode 49 (irrep X5+) for temp 152. Process took 7.231123685836792s (0.12051872809727987 minutes)
# Estimated 0.45803619978825255 hours to completion.
# Executing mode 55 , irrep X5+ for temp 152
# Completed mode 55 (irrep X5+) for temp 152. Process took 5.103590965270996s (0.08505984942118326 minutes)
# Estimated 0.45531766092966475 hours to completion.
# Executing mode 16 , irrep M2- for temp 152
# Completed mode 16 (irrep M2-) for temp 152. Process took 7.944649934768677s (0.1324108322461446 minutes)
# Estimated 0.45484912379496334 hours to completion.
# Executing mode 88 , irrep M2- for temp 152
# Completed mode 88 (irrep M2-) for temp 152. Process took 7.358244895935059s (0.12263741493225097 minutes)
# Estimated 0.4538913144603852 hours to completion.
# Executing mode 19 , irrep M5- for temp 152
# Completed mode 19 (irrep M5-) for temp 152. Process took 6.12497615814209s (0.10208293596903482 minutes)
# Estimated 0.45197378193373944 hours to completion.
# Executing mode 91 , irrep M5- for temp 152
# Completed mode 91 (irrep M5-) for temp 152. Process took 5.078139305114746s (0.08463565508524577 minutes)
# Estimated 0.4492772027623584 hours to completion.
# Executing mode 31 , irrep GM5- for temp 152
# Completed mode 31 (irrep GM5-) for temp 152. Process took 5.031219482421875s (0.08385365804036458 minutes)
# Estimated 0.44657279528263544 hours to completion.
# Executing mode 34 , irrep R2- for temp 152
# Completed mode 34 (irrep R2-) for temp 152. Process took 6.937520980834961s (0.11562534968058268 minutes)
# Estimated 0.4452819326926206 hours to completion.
# Executing mode 35 , irrep R3- for temp 152
# Completed mode 35 (irrep R3-) for temp 152. Process took 6.859474420547485s (0.11432457367579142 minutes)
# Estimated 0.44392211712339297 hours to completion.
# Executing mode 37 , irrep R4- for temp 152
# Completed mode 37 (irrep R4-) for temp 152. Process took 5.218700885772705s (0.08697834809621176 minutes)
# Estimated 0.44139113654994 hours to completion.
# Executing mode 40 , irrep R5- for temp 152
# Completed mode 40 (irrep R5-) for temp 152. Process took 4.734475612640381s (0.07890792687733968 minutes)
# Estimated 0.4385441701842679 hours to completion.
# Executing mode 46 , irrep X2+ for temp 152
# Completed mode 46 (irrep X2+) for temp 152. Process took 5.04685115814209s (0.08411418596903483 minutes)
# Estimated 0.43594231683560064 hours to completion.
# Executing mode 61 , irrep X3- for temp 152
# Completed mode 61 (irrep X3-) for temp 152. Process took 6.797270774841309s (0.11328784624735515 minutes)
# Estimated 0.4345509594737315 hours to completion.
# Executing mode 64 , irrep X5- for temp 152
# Completed mode 64 (irrep X5-) for temp 152. Process took 4.858819246292114s (0.08098032077153523 minutes)
# Estimated 0.4318534728032743 hours to completion.
# Executing mode 70 , irrep M1+ for temp 152
# Completed mode 70 (irrep M1+) for temp 152. Process took 5.156541585922241s (0.0859423597653707 minutes)
# Estimated 0.42937831968896917 hours to completion.
# Executing mode 73 , irrep M2+ for temp 152
# Completed mode 73 (irrep M2+) for temp 152. Process took 4.906006813049316s (0.08176678021748861 minutes)
# Estimated 0.4267599826199667 hours to completion.
# Executing mode 76 , irrep M3+ for temp 152
# Completed mode 76 (irrep M3+) for temp 152. Process took 10.093934297561646s (0.1682322382926941 minutes)
# Estimated 0.4274961587767931 hours to completion.
# Executing mode 79 , irrep M4+ for temp 152
# Completed mode 79 (irrep M4+) for temp 152. Process took 6.679166793823242s (0.1113194465637207 minutes)
# Estimated 0.4260031251521125 hours to completion.
# Executing mode 82 , irrep M5+ for temp 152
# Completed mode 82 (irrep M5+) for temp 152. Process took 4.570873975753784s (0.07618123292922974 minutes)
# Estimated 0.4231856994330883 hours to completion.
# Executing mode 0 , irrep nomodes for temp 175
# Completed mode 0 (irrep nomodes) for temp 175. Process took 5.971819162368774s (0.09953031937281291 minutes)
# Estimated 0.42126066018803526 hours to completion.
# Executing mode 1 , irrep GM4- for temp 175
# Completed mode 1 (irrep GM4-) for temp 175. Process took 5.872030019760132s (0.0978671669960022 minutes)
# Estimated 0.41927973069265634 hours to completion.
# Executing mode 25 , irrep GM4- for temp 175
# Completed mode 25 (irrep GM4-) for temp 175. Process took 5.999966859817505s (0.09999944766362508 minutes)
# Estimated 0.4173819430239566 hours to completion.
# Executing mode 28 , irrep GM4- for temp 175
# Completed mode 28 (irrep GM4-) for temp 175. Process took 5.239593982696533s (0.08732656637827556 minutes)
# Estimated 0.41503756562277444 hours to completion.
# Executing mode 4 , irrep R5+ for temp 175
# Completed mode 4 (irrep R5+) for temp 175. Process took 6.472205877304077s (0.10787009795506795 minutes)
# Estimated 0.41343006619661604 hours to completion.
# Executing mode 7 , irrep X1+ for temp 175
# Completed mode 7 (irrep X1+) for temp 175. Process took 7.179309844970703s (0.11965516408284506 minutes)
# Estimated 0.41222756975401215 hours to completion.
# Executing mode 43 , irrep X1+ for temp 175
# Completed mode 43 (irrep X1+) for temp 175. Process took 5.046449899673462s (0.08410749832789104 minutes)
# Estimated 0.4097954704312311 hours to completion.
# Executing mode 10 , irrep X5+ for temp 175
# Completed mode 10 (irrep X5+) for temp 175. Process took 7.07845139503479s (0.1179741899172465 minutes)
# Estimated 0.40852462246557303 hours to completion.
# Executing mode 49 , irrep X5+ for temp 175
# Completed mode 49 (irrep X5+) for temp 175. Process took 6.234058618545532s (0.10390097697575887 minutes)
# Estimated 0.406772780418396 hours to completion.
# Executing mode 55 , irrep X5+ for temp 175
# Completed mode 55 (irrep X5+) for temp 175. Process took 4.875067710876465s (0.08125112851460775 minutes)
# Estimated 0.40427588249554963 hours to completion.
# Executing mode 16 , irrep M2- for temp 175
# Completed mode 16 (irrep M2-) for temp 175. Process took 7.5114428997039795s (0.12519071499506632 minutes)
# Estimated 0.403225918684353 hours to completion.
# Executing mode 88 , irrep M2- for temp 175
# Completed mode 88 (irrep M2-) for temp 175. Process took 6.380571365356445s (0.10634285608927409 minutes)
# Estimated 0.40155397693150574 hours to completion.
# Executing mode 19 , irrep M5- for temp 175
# Completed mode 19 (irrep M5-) for temp 175. Process took 5.529748201370239s (0.09216247002283733 minutes)
# Estimated 0.3994311341459977 hours to completion.
# Executing mode 91 , irrep M5- for temp 175
# Completed mode 91 (irrep M5-) for temp 175. Process took 4.843825101852417s (0.08073041836420695 minutes)
# Estimated 0.3969602690058979 hours to completion.
# Executing mode 31 , irrep GM5- for temp 175
# Completed mode 31 (irrep GM5-) for temp 175. Process took 4.999997615814209s (0.08333329359690349 minutes)
# Estimated 0.3945881164041638 hours to completion.
# Executing mode 34 , irrep R2- for temp 175
# Completed mode 34 (irrep R2-) for temp 175. Process took 6.28123140335083s (0.10468719005584717 minutes)
# Estimated 0.3928833463590418 hours to completion.
# Executing mode 35 , irrep R3- for temp 175
# Completed mode 35 (irrep R3-) for temp 175. Process took 5.827103137969971s (0.09711838563283284 minutes)
# Estimated 0.39094986274401344 hours to completion.
# Executing mode 37 , irrep R4- for temp 175
# Completed mode 37 (irrep R4-) for temp 175. Process took 5.157304763793945s (0.08595507939656576 minutes)
# Estimated 0.388689135393453 hours to completion.
# Executing mode 40 , irrep R5- for temp 175
# Completed mode 40 (irrep R5-) for temp 175. Process took 5.67298150062561s (0.09454969167709351 minutes)
# Estimated 0.38669409967991525 hours to completion.
# Executing mode 46 , irrep X2+ for temp 175
# Completed mode 46 (irrep X2+) for temp 175. Process took 5.093038082122803s (0.08488396803538005 minutes)
# Estimated 0.38442495570207635 hours to completion.
# Executing mode 61 , irrep X3- for temp 175
# Completed mode 61 (irrep X3-) for temp 175. Process took 5.624738693237305s (0.09374564488728841 minutes)
# Estimated 0.38242323053591626 hours to completion.
# Executing mode 64 , irrep X5- for temp 175
# Completed mode 64 (irrep X5-) for temp 175. Process took 4.972943067550659s (0.08288238445917766 minutes)
# Estimated 0.3801204714179039 hours to completion.
# Executing mode 70 , irrep M1+ for temp 175
# Completed mode 70 (irrep M1+) for temp 175. Process took 4.886512279510498s (0.08144187132517497 minutes)
# Estimated 0.37779145955634985 hours to completion.
# Executing mode 73 , irrep M2+ for temp 175
# Completed mode 73 (irrep M2+) for temp 175. Process took 5.248974323272705s (0.08748290538787842 minutes)
# Estimated 0.37564421336909737 hours to completion.
# Executing mode 76 , irrep M3+ for temp 175
# Completed mode 76 (irrep M3+) for temp 175. Process took 6.190609931945801s (0.10317683219909668 minutes)
# Estimated 0.3739360623919376 hours to completion.
# Executing mode 79 , irrep M4+ for temp 175
# Completed mode 79 (irrep M4+) for temp 175. Process took 5.986579895019531s (0.09977633158365885 minutes)
# Estimated 0.37213596064603544 hours to completion.
# Executing mode 82 , irrep M5+ for temp 175
# Completed mode 82 (irrep M5+) for temp 175. Process took 4.839491367340088s (0.08065818945566813 minutes)
# Estimated 0.3698280738194783 hours to completion.
# Executing mode 0 , irrep nomodes for temp 200
# Completed mode 0 (irrep nomodes) for temp 200. Process took 8.734785079956055s (0.1455797513326009 minutes)
# Estimated 0.3692449131992712 hours to completion.
# Executing mode 1 , irrep GM4- for temp 200
# Completed mode 1 (irrep GM4-) for temp 200. Process took 6.576746463775635s (0.10961244106292725 minutes)
# Estimated 0.36769846977785364 hours to completion.
# Executing mode 25 , irrep GM4- for temp 200
# Completed mode 25 (irrep GM4-) for temp 200. Process took 6.641692161560059s (0.11069486935933431 minutes)
# Estimated 0.36617580722063636 hours to completion.
# Executing mode 28 , irrep GM4- for temp 200
# Completed mode 28 (irrep GM4-) for temp 200. Process took 4.984361171722412s (0.08307268619537353 minutes)
# Estimated 0.36394636132257835 hours to completion.
# Executing mode 4 , irrep R5+ for temp 200
# Completed mode 4 (irrep R5+) for temp 200. Process took 8.711480140686035s (0.14519133567810058 minutes)
# Estimated 0.36328934675502406 hours to completion.
# Executing mode 7 , irrep X1+ for temp 200
# Completed mode 7 (irrep X1+) for temp 200. Process took 7.879194736480713s (0.13131991227467854 minutes)
# Estimated 0.3622630012373552 hours to completion.
# Executing mode 43 , irrep X1+ for temp 200
# Completed mode 43 (irrep X1+) for temp 200. Process took 5.268850803375244s (0.08781418005625406 minutes)
# Estimated 0.36015306694080385 hours to completion.
# Executing mode 10 , irrep X5+ for temp 200
# Completed mode 10 (irrep X5+) for temp 200. Process took 8.873955726623535s (0.14789926211039225 minutes)
# Estimated 0.3595087807587903 hours to completion.
# Executing mode 49 , irrep X5+ for temp 200
# Completed mode 49 (irrep X5+) for temp 200. Process took 6.704041242599487s (0.11173402070999146 minutes)
# Estimated 0.35797274814711677 hours to completion.
# Executing mode 55 , irrep X5+ for temp 200
# Completed mode 55 (irrep X5+) for temp 200. Process took 4.927194833755493s (0.08211991389592489 minutes)
# Estimated 0.3557310086237516 hours to completion.
# Executing mode 16 , irrep M2- for temp 200
# Completed mode 16 (irrep M2-) for temp 200. Process took 8.317916631698608s (0.1386319438616435 minutes)
# Estimated 0.35482371374170896 hours to completion.
# Executing mode 88 , irrep M2- for temp 200
# Completed mode 88 (irrep M2-) for temp 200. Process took 7.22386622428894s (0.12039777040481567 minutes)
# Estimated 0.35347558440534976 hours to completion.
# Executing mode 19 , irrep M5- for temp 200
# Completed mode 19 (irrep M5-) for temp 200. Process took 11.005231380462646s (0.18342052300771078 minutes)
# Estimated 0.35355927925344344 hours to completion.
# Executing mode 91 , irrep M5- for temp 200
# Completed mode 91 (irrep M5-) for temp 200. Process took 4.736333131790161s (0.07893888552983602 minutes)
# Estimated 0.351240046227005 hours to completion.
# Executing mode 31 , irrep GM5- for temp 200
# Completed mode 31 (irrep GM5-) for temp 200. Process took 5.094130277633667s (0.08490217129389445 minutes)
# Estimated 0.3490673743817541 hours to completion.
# Executing mode 34 , irrep R2- for temp 200
# Completed mode 34 (irrep R2-) for temp 200. Process took 6.505064010620117s (0.10841773351033529 minutes)
# Estimated 0.34742384477956406 hours to completion.
# Executing mode 35 , irrep R3- for temp 200
# Completed mode 35 (irrep R3-) for temp 200. Process took 6.798938751220703s (0.11331564585367838 minutes)
# Estimated 0.3458850380547388 hours to completion.
# Executing mode 37 , irrep R4- for temp 200
# Completed mode 37 (irrep R4-) for temp 200. Process took 5.240607738494873s (0.08734346230824788 minutes)
# Estimated 0.3437814745949764 hours to completion.
# Executing mode 40 , irrep R5- for temp 200
# Completed mode 40 (irrep R5-) for temp 200. Process took 4.868718385696411s (0.08114530642827351 minutes)
# Estimated 0.34155417779995423 hours to completion.
# Executing mode 46 , irrep X2+ for temp 200
# Completed mode 46 (irrep X2+) for temp 200. Process took 4.992790699005127s (0.08321317831675211 minutes)
# Estimated 0.3393817506708125 hours to completion.
# Executing mode 61 , irrep X3- for temp 200
# Completed mode 61 (irrep X3-) for temp 200. Process took 6.456811189651489s (0.10761351982752482 minutes)
# Estimated 0.33772773502601516 hours to completion.
# Executing mode 64 , irrep X5- for temp 200
# Completed mode 64 (irrep X5-) for temp 200. Process took 4.7380664348602295s (0.07896777391433715 minutes)
# Estimated 0.3354819975267128 hours to completion.
# Executing mode 70 , irrep M1+ for temp 200
# Completed mode 70 (irrep M1+) for temp 200. Process took 6.515822649002075s (0.10859704415003459 minutes)
# Estimated 0.3338512391526823 hours to completion.
# Executing mode 73 , irrep M2+ for temp 200
# Completed mode 73 (irrep M2+) for temp 200. Process took 4.969342947006226s (0.08282238245010376 minutes)
# Estimated 0.33169949145686956 hours to completion.
# Executing mode 76 , irrep M3+ for temp 200
# Completed mode 76 (irrep M3+) for temp 200. Process took 6.733811378479004s (0.11223018964131673 minutes)
# Estimated 0.33014247877481906 hours to completion.
# Executing mode 79 , irrep M4+ for temp 200
# Completed mode 79 (irrep M4+) for temp 200. Process took 6.578433513641357s (0.10964055856068929 minutes)
# Estimated 0.32853063702830126 hours to completion.
# Executing mode 82 , irrep M5+ for temp 200
# Completed mode 82 (irrep M5+) for temp 200. Process took 4.733432054519653s (0.07889053424199423 minutes)
# Estimated 0.3263182176373623 hours to completion.
# Executing mode 0 , irrep nomodes for temp 225
# Completed mode 0 (irrep nomodes) for temp 225. Process took 9.438544988632202s (0.15730908314387004 minutes)
# Estimated 0.32562424369141124 hours to completion.
# Executing mode 1 , irrep GM4- for temp 225
# Completed mode 1 (irrep GM4-) for temp 225. Process took 5.431210041046143s (0.09052016735076904 minutes)
# Estimated 0.3236374985517525 hours to completion.
# Executing mode 25 , irrep GM4- for temp 225
# Completed mode 25 (irrep GM4-) for temp 225. Process took 6.59924578666687s (0.10998742977778117 minutes)
# Estimated 0.3220222968356778 hours to completion.
# Executing mode 28 , irrep GM4- for temp 225
# Completed mode 28 (irrep GM4-) for temp 225. Process took 4.922111511230469s (0.08203519185384114 minutes)
# Estimated 0.31988527637767983 hours to completion.
# Executing mode 4 , irrep R5+ for temp 225
# Completed mode 4 (irrep R5+) for temp 225. Process took 8.96881890296936s (0.14948031504948933 minutes)
# Estimated 0.31899598792958717 hours to completion.
# Executing mode 7 , irrep X1+ for temp 225
# Completed mode 7 (irrep X1+) for temp 225. Process took 9.221029043197632s (0.1536838173866272 minutes)
# Estimated 0.3181639410401621 hours to completion.
# Executing mode 43 , irrep X1+ for temp 225
# Completed mode 43 (irrep X1+) for temp 225. Process took 5.1697492599487305s (0.08616248766581218 minutes)
# Estimated 0.31609950716678914 hours to completion.
# Executing mode 10 , irrep X5+ for temp 225
# Completed mode 10 (irrep X5+) for temp 225. Process took 9.140986204147339s (0.15234977006912231 minutes)
# Estimated 0.31521696596052134 hours to completion.
# Executing mode 49 , irrep X5+ for temp 225
# Completed mode 49 (irrep X5+) for temp 225. Process took 6.655152320861816s (0.11091920534769693 minutes)
# Estimated 0.3135881970500388 hours to completion.
# Executing mode 55 , irrep X5+ for temp 225
# Completed mode 55 (irrep X5+) for temp 225. Process took 4.7647247314453125s (0.07941207885742188 minutes)
# Estimated 0.3114103814551381 hours to completion.
# Executing mode 16 , irrep M2- for temp 225
# Completed mode 16 (irrep M2-) for temp 225. Process took 9.783527612686157s (0.1630587935447693 minutes)
# Estimated 0.3106768461037846 hours to completion.
# Executing mode 88 , irrep M2- for temp 225
# Completed mode 88 (irrep M2-) for temp 225. Process took 7.375007152557373s (0.12291678587595621 minutes)
# Estimated 0.3092399363556584 hours to completion.
# Executing mode 19 , irrep M5- for temp 225
# Completed mode 19 (irrep M5-) for temp 225. Process took 11.389901638031006s (0.18983169396718344 minutes)
# Estimated 0.3089176570286826 hours to completion.
# Executing mode 91 , irrep M5- for temp 225
# Completed mode 91 (irrep M5-) for temp 225. Process took 4.782202482223511s (0.07970337470372518 minutes)
# Estimated 0.30673804382483166 hours to completion.
# Executing mode 31 , irrep GM5- for temp 225
# Completed mode 31 (irrep GM5-) for temp 225. Process took 4.740967512130737s (0.07901612520217896 minutes)
# Estimated 0.30455678894694915 hours to completion.
# Executing mode 34 , irrep R2- for temp 225
# Completed mode 34 (irrep R2-) for temp 225. Process took 8.868740320205688s (0.1478123386700948 minutes)
# Estimated 0.3034996411163411 hours to completion.
# Executing mode 35 , irrep R3- for temp 225
# Completed mode 35 (irrep R3-) for temp 225. Process took 9.36901068687439s (0.15615017811457316 minutes)
# Estimated 0.30256030906290093 hours to completion.
# Executing mode 37 , irrep R4- for temp 225
# Completed mode 37 (irrep R4-) for temp 225. Process took 5.02906608581543s (0.08381776809692383 minutes)
# Estimated 0.30045723417401315 hours to completion.
# Executing mode 40 , irrep R5- for temp 225
# Completed mode 40 (irrep R5-) for temp 225. Process took 5.07001519203186s (0.084500253200531 minutes)
# Estimated 0.29837264509710376 hours to completion.
# Executing mode 46 , irrep X2+ for temp 225
# Completed mode 46 (irrep X2+) for temp 225. Process took 5.219913959503174s (0.08699856599171957 minutes)
# Estimated 0.2963341517202438 hours to completion.
# Executing mode 61 , irrep X3- for temp 225
# Completed mode 61 (irrep X3-) for temp 225. Process took 7.062625408172607s (0.11771042346954345 minutes)
# Estimated 0.294771998428039 hours to completion.
# Executing mode 64 , irrep X5- for temp 225
# Completed mode 64 (irrep X5-) for temp 225. Process took 4.890686273574829s (0.08151143789291382 minutes)
# Estimated 0.2926579254761267 hours to completion.
# Executing mode 70 , irrep M1+ for temp 225
# Completed mode 70 (irrep M1+) for temp 225. Process took 5.031324625015259s (0.08385541041692098 minutes)
# Estimated 0.29058707462488353 hours to completion.
# Executing mode 73 , irrep M2+ for temp 225
# Completed mode 73 (irrep M2+) for temp 225. Process took 4.890548944473267s (0.08150914907455445 minutes)
# Estimated 0.28848877378796167 hours to completion.
# Executing mode 76 , irrep M3+ for temp 225
# Completed mode 76 (irrep M3+) for temp 225. Process took 7.061849355697632s (0.1176974892616272 minutes)
# Estimated 0.2869273415422128 hours to completion.
# Executing mode 79 , irrep M4+ for temp 225
# Completed mode 79 (irrep M4+) for temp 225. Process took 8.017757177352905s (0.13362928628921508 minutes)
# Estimated 0.2855918720452639 hours to completion.
# Executing mode 82 , irrep M5+ for temp 225
# Completed mode 82 (irrep M5+) for temp 225. Process took 4.967779636383057s (0.08279632727305095 minutes)
# Estimated 0.2835207815965017 hours to completion.
# Executing mode 0 , irrep nomodes for temp 250
# Completed mode 0 (irrep nomodes) for temp 250. Process took 9.336664915084839s (0.15561108191808065 minutes)
# Estimated 0.2824853151562618 hours to completion.
# Executing mode 1 , irrep GM4- for temp 250
# Completed mode 1 (irrep GM4-) for temp 250. Process took 6.72508692741394s (0.11208478212356568 minutes)
# Estimated 0.2808258370093789 hours to completion.
# Executing mode 25 , irrep GM4- for temp 250
# Completed mode 25 (irrep GM4-) for temp 250. Process took 7.376074552536011s (0.12293457587560018 minutes)
# Estimated 0.2793139356871446 hours to completion.
# Executing mode 28 , irrep GM4- for temp 250
# Completed mode 28 (irrep GM4-) for temp 250. Process took 4.906416893005371s (0.08177361488342286 minutes)
# Estimated 0.27723486054540714 hours to completion.
# Executing mode 4 , irrep R5+ for temp 250
# Completed mode 4 (irrep R5+) for temp 250. Process took 6.718890428543091s (0.11198150714238485 minutes)
# Estimated 0.27557061193905613 hours to completion.
# Executing mode 7 , irrep X1+ for temp 250
# Completed mode 7 (irrep X1+) for temp 250. Process took 9.531232833862305s (0.15885388056437175 minutes)
# Estimated 0.27452925539016726 hours to completion.
# Executing mode 43 , irrep X1+ for temp 250
# Completed mode 43 (irrep X1+) for temp 250. Process took 5.137700319290161s (0.08562833865483602 minutes)
# Estimated 0.27250637639474434 hours to completion.
# Executing mode 10 , irrep X5+ for temp 250
# Completed mode 10 (irrep X5+) for temp 250. Process took 9.393919706344604s (0.15656532843907675 minutes)
# Estimated 0.271413766877233 hours to completion.
# Executing mode 49 , irrep X5+ for temp 250
# Completed mode 49 (irrep X5+) for temp 250. Process took 7.515602350234985s (0.1252600391705831 minutes)
# Estimated 0.26990266184012096 hours to completion.
# Executing mode 55 , irrep X5+ for temp 250
# Completed mode 55 (irrep X5+) for temp 250. Process took 5.115856409072876s (0.08526427348454793 minutes)
# Estimated 0.267876603381052 hours to completion.
# Executing mode 16 , irrep M2- for temp 250
# Completed mode 16 (irrep M2-) for temp 250. Process took 8.113587141036987s (0.13522645235061645 minutes)
# Estimated 0.26648528554505774 hours to completion.
# Executing mode 88 , irrep M2- for temp 250
# Completed mode 88 (irrep M2-) for temp 250. Process took 7.036275863647461s (0.11727126439412434 minutes)
# Estimated 0.26486206282035235 hours to completion.
# Executing mode 19 , irrep M5- for temp 250
# Completed mode 19 (irrep M5-) for temp 250. Process took 6.140887022018433s (0.10234811703364054 minutes)
# Estimated 0.2630520987789361 hours to completion.
# Executing mode 91 , irrep M5- for temp 250
# Completed mode 91 (irrep M5-) for temp 250. Process took 5.093711614608765s (0.08489519357681274 minutes)
# Estimated 0.26103108931710045 hours to completion.
# Executing mode 31 , irrep GM5- for temp 250
# Completed mode 31 (irrep GM5-) for temp 250. Process took 5.06252121925354s (0.08437535365422567 minutes)
# Estimated 0.2590097787343209 hours to completion.
# Executing mode 34 , irrep R2- for temp 250
# Completed mode 34 (irrep R2-) for temp 250. Process took 7.939639329910278s (0.13232732216517132 minutes)
# Estimated 0.25756365465277903 hours to completion.
# Executing mode 35 , irrep R3- for temp 250
# Completed mode 35 (irrep R3-) for temp 250. Process took 7.293647050857544s (0.12156078418095907 minutes)
# Estimated 0.25598385194969536 hours to completion.
# Executing mode 37 , irrep R4- for temp 250
# Completed mode 37 (irrep R4-) for temp 250. Process took 5.282262802124023s (0.08803771336873373 minutes)
# Estimated 0.25401106475056084 hours to completion.
# Executing mode 40 , irrep R5- for temp 250
# Completed mode 40 (irrep R5-) for temp 250. Process took 4.8313679695129395s (0.08052279949188232 minutes)
# Estimated 0.25195702966302636 hours to completion.
# Executing mode 46 , irrep X2+ for temp 250
# Completed mode 46 (irrep X2+) for temp 250. Process took 5.403350114822388s (0.09005583524703979 minutes)
# Estimated 0.25001775770856627 hours to completion.
# Executing mode 61 , irrep X3- for temp 250
# Completed mode 61 (irrep X3-) for temp 250. Process took 7.299772024154663s (0.12166286706924438 minutes)
# Estimated 0.24843635817084994 hours to completion.
# Executing mode 64 , irrep X5- for temp 250
# Completed mode 64 (irrep X5-) for temp 250. Process took 5.367856979370117s (0.08946428298950196 minutes)
# Estimated 0.24649466166940723 hours to completion.
# Executing mode 70 , irrep M1+ for temp 250
# Completed mode 70 (irrep M1+) for temp 250. Process took 5.3342204093933105s (0.08890367348988851 minutes)
# Estimated 0.2445510901910579 hours to completion.
# Executing mode 73 , irrep M2+ for temp 250
# Completed mode 73 (irrep M2+) for temp 250. Process took 4.796257495880127s (0.07993762493133545 minutes)
# Estimated 0.242515038785427 hours to completion.
# Executing mode 76 , irrep M3+ for temp 250
# Completed mode 76 (irrep M3+) for temp 250. Process took 7.451945781707764s (0.12419909636179606 minutes)
# Estimated 0.24095782480228725 hours to completion.
# Executing mode 79 , irrep M4+ for temp 250
# Completed mode 79 (irrep M4+) for temp 250. Process took 7.297154188156128s (0.1216192364692688 minutes)
# Estimated 0.23936864233386612 hours to completion.
# Executing mode 82 , irrep M5+ for temp 250
# Completed mode 82 (irrep M5+) for temp 250. Process took 5.796559810638428s (0.09660933017730713 minutes)
# Estimated 0.23751488626003264 hours to completion.
# Executing mode 0 , irrep nomodes for temp 275
# Completed mode 0 (irrep nomodes) for temp 275. Process took 9.280214071273804s (0.15467023452123005 minutes)
# Estimated 0.23626092997503112 hours to completion.
# Executing mode 1 , irrep GM4- for temp 275
# Completed mode 1 (irrep GM4-) for temp 275. Process took 6.860738515853882s (0.11434564193089804 minutes)
# Estimated 0.23458479964344264 hours to completion.
# Executing mode 25 , irrep GM4- for temp 275
# Completed mode 25 (irrep GM4-) for temp 275. Process took 7.0624518394470215s (0.11770753065745036 minutes)
# Estimated 0.23294034462904095 hours to completion.
# Executing mode 28 , irrep GM4- for temp 275
# Completed mode 28 (irrep GM4-) for temp 275. Process took 6.749709129333496s (0.11249515215555826 minutes)
# Estimated 0.23124127582347756 hours to completion.
# Executing mode 4 , irrep R5+ for temp 275
# Completed mode 4 (irrep R5+) for temp 275. Process took 6.0927629470825195s (0.10154604911804199 minutes)
# Estimated 0.22943327146417955 hours to completion.
# Executing mode 7 , irrep X1+ for temp 275
# Completed mode 7 (irrep X1+) for temp 275. Process took 8.625943660736084s (0.14376572767893472 minutes)
# Estimated 0.22803519255227153 hours to completion.
# Executing mode 43 , irrep X1+ for temp 275
# Completed mode 43 (irrep X1+) for temp 275. Process took 5.006392002105713s (0.08343986670176189 minutes)
# Estimated 0.22605105443326287 hours to completion.
# Executing mode 10 , irrep X5+ for temp 275
# Completed mode 10 (irrep X5+) for temp 275. Process took 8.587466478347778s (0.1431244413057963 minutes)
# Estimated 0.22463619888981892 hours to completion.
# Executing mode 49 , irrep X5+ for temp 275
# Completed mode 49 (irrep X5+) for temp 275. Process took 7.06248664855957s (0.11770811080932617 minutes)
# Estimated 0.22297549713452658 hours to completion.
# Executing mode 55 , irrep X5+ for temp 275
# Completed mode 55 (irrep X5+) for temp 275. Process took 4.88965368270874s (0.08149422804514567 minutes)
# Estimated 0.22097830073642402 hours to completion.
# Executing mode 16 , irrep M2- for temp 275
# Completed mode 16 (irrep M2-) for temp 275. Process took 6.673002481460571s (0.11121670802434286 minutes)
# Estimated 0.21925733507467263 hours to completion.
# Executing mode 88 , irrep M2- for temp 275
# Completed mode 88 (irrep M2-) for temp 275. Process took 6.484260559082031s (0.10807100931803386 minutes)
# Estimated 0.21750692215579298 hours to completion.
# Executing mode 19 , irrep M5- for temp 275
# Completed mode 19 (irrep M5-) for temp 275. Process took 5.921941518783569s (0.09869902531305949 minutes)
# Estimated 0.2156728502473225 hours to completion.
# Executing mode 91 , irrep M5- for temp 275
# Completed mode 91 (irrep M5-) for temp 275. Process took 5.937517881393433s (0.0989586313565572 minutes)
# Estimated 0.21384269883955156 hours to completion.
# Executing mode 31 , irrep GM5- for temp 275
# Completed mode 31 (irrep GM5-) for temp 275. Process took 5.103126049041748s (0.08505210081736246 minutes)
# Estimated 0.21189371029191892 hours to completion.
# Executing mode 34 , irrep R2- for temp 275
# Completed mode 34 (irrep R2-) for temp 275. Process took 11.021846294403076s (0.18369743824005128 minutes)
# Estimated 0.21079260748978776 hours to completion.
# Executing mode 35 , irrep R3- for temp 275
# Completed mode 35 (irrep R3-) for temp 275. Process took 8.92512321472168s (0.14875205357869467 minutes)
# Estimated 0.20937971513613554 hours to completion.
# Executing mode 37 , irrep R4- for temp 275
# Completed mode 37 (irrep R4-) for temp 275. Process took 5.184319019317627s (0.08640531698862712 minutes)
# Estimated 0.2074381528960334 hours to completion.
# Executing mode 40 , irrep R5- for temp 275
# Completed mode 40 (irrep R5-) for temp 275. Process took 4.820971488952637s (0.08034952481587727 minutes)
# Estimated 0.20545103781499477 hours to completion.
# Executing mode 46 , irrep X2+ for temp 275
# Completed mode 46 (irrep X2+) for temp 275. Process took 5.24152684211731s (0.08735878070195516 minutes)
# Estimated 0.20352633934320702 hours to completion.
# Executing mode 61 , irrep X3- for temp 275
# Completed mode 61 (irrep X3-) for temp 275. Process took 7.578233957290649s (0.12630389928817748 minutes)
# Estimated 0.20191781455454444 hours to completion.
# Executing mode 64 , irrep X5- for temp 275
# Completed mode 64 (irrep X5-) for temp 275. Process took 4.7501184940338135s (0.07916864156723022 minutes)
# Estimated 0.19993212807495722 hours to completion.
# Executing mode 70 , irrep M1+ for temp 275
# Completed mode 70 (irrep M1+) for temp 275. Process took 4.890609264373779s (0.08151015440622965 minutes)
# Estimated 0.19797030453347206 hours to completion.
# Executing mode 73 , irrep M2+ for temp 275
# Completed mode 73 (irrep M2+) for temp 275. Process took 5.125075578689575s (0.08541792631149292 minutes)
# Estimated 0.19604363107515707 hours to completion.
# ...
# Completed mode 1 (irrep GM4-) for temp 350. Process took 7.165187835693359s (0.119419797261556 minutes)
# Estimated 0.1360054033098657 hours to completion.
# Executing mode 25 , irrep GM4- for temp 350
# Completed mode 25 (irrep GM4-) for temp 350. Process took 9.439433574676514s (0.15732389291127521 minutes)
# Estimated 0.13454109521139235 hours to completion.
# Executing mode 28 , irrep GM4- for temp 350
# Completed mode 28 (irrep GM4-) for temp 350. Process took 4.865279197692871s (0.08108798662821452 minutes)
# Estimated 0.13271127034906247 hours to completion.
# Executing mode 4 , irrep R5+ for temp 350
# Completed mode 4 (irrep R5+) for temp 350. Process took 7.264667749404907s (0.12107779582341512 minutes)
# Estimated 0.13106911994182702 hours to completion.
# Executing mode 7 , irrep X1+ for temp 350
# Completed mode 7 (irrep X1+) for temp 350. Process took 8.905701875686646s (0.14842836459477743 minutes)
# Estimated 0.12954811658260326 hours to completion.
# Executing mode 43 , irrep X1+ for temp 350
# Completed mode 43 (irrep X1+) for temp 350. Process took 4.842417001724243s (0.08070695002873739 minutes)
# Estimated 0.12771870642410338 hours to completion.
# Executing mode 10 , irrep X5+ for temp 350
# Completed mode 10 (irrep X5+) for temp 350. Process took 6.013477087020874s (0.10022461811701457 minutes)
# Estimated 0.12597819944842162 hours to completion.
# Executing mode 49 , irrep X5+ for temp 350
# Completed mode 49 (irrep X5+) for temp 350. Process took 7.802114248275757s (0.1300352374712626 minutes)
# Estimated 0.12436641267550891 hours to completion.
# Executing mode 55 , irrep X5+ for temp 350
# Completed mode 55 (irrep X5+) for temp 350. Process took 4.580212354660034s (0.07633687257766723 minutes)
# Estimated 0.12252371876154627 hours to completion.
# Executing mode 16 , irrep M2- for temp 350
# Completed mode 16 (irrep M2-) for temp 350. Process took 6.979452610015869s (0.11632421016693115 minutes)
# Estimated 0.12085110569905273 hours to completion.
# Executing mode 88 , irrep M2- for temp 350
# Completed mode 88 (irrep M2-) for temp 350. Process took 6.752478361129761s (0.11254130601882935 minutes)
# Estimated 0.11916117849713521 hours to completion.
# Executing mode 19 , irrep M5- for temp 350
# Completed mode 19 (irrep M5-) for temp 350. Process took 8.00454831123352s (0.13340913852055866 minutes)
# Estimated 0.11755350814223242 hours to completion.
# Executing mode 91 , irrep M5- for temp 350
# Completed mode 91 (irrep M5-) for temp 350. Process took 5.916958570480347s (0.09861597617467245 minutes)
# Estimated 0.11580469695918251 hours to completion.
# Executing mode 31 , irrep GM5- for temp 350
# Completed mode 31 (irrep GM5-) for temp 350. Process took 5.049898862838745s (0.08416498104731242 minutes)
# Estimated 0.11400084833234375 hours to completion.
# Executing mode 34 , irrep R2- for temp 350
# Completed mode 34 (irrep R2-) for temp 350. Process took 8.184481143951416s (0.13640801906585692 minutes)
# Estimated 0.11239769488874109 hours to completion.
# Executing mode 35 , irrep R3- for temp 350
# Completed mode 35 (irrep R3-) for temp 350. Process took 7.819965600967407s (0.13033276001612346 minutes)
# Estimated 0.11076729091063887 hours to completion.
# Executing mode 37 , irrep R4- for temp 350
# Completed mode 37 (irrep R4-) for temp 350. Process took 4.880627393722534s (0.08134378989537557 minutes)
# Estimated 0.10895451875196563 hours to completion.
# Executing mode 40 , irrep R5- for temp 350
# Completed mode 40 (irrep R5-) for temp 350. Process took 5.006632328033447s (0.08344387213389079 minutes)
# Estimated 0.10715241846053795 hours to completion.
# Executing mode 46 , irrep X2+ for temp 350
# Completed mode 46 (irrep X2+) for temp 350. Process took 4.934301137924194s (0.08223835229873658 minutes)
# Estimated 0.10534892894961369 hours to completion.
# Executing mode 61 , irrep X3- for temp 350
# Completed mode 61 (irrep X3-) for temp 350. Process took 7.249481439590454s (0.1208246906598409 minutes)
# Estimated 0.10368101345577872 hours to completion.
# Executing mode 64 , irrep X5- for temp 350
# Completed mode 64 (irrep X5-) for temp 350. Process took 5.366116046905518s (0.0894352674484253 minutes)
# Estimated 0.10190502287681064 hours to completion.
# Executing mode 70 , irrep M1+ for temp 350
# Completed mode 70 (irrep M1+) for temp 350. Process took 4.928816080093384s (0.08214693466822307 minutes)
# Estimated 0.10010693474569961 hours to completion.
# Executing mode 73 , irrep M2+ for temp 350
# Completed mode 73 (irrep M2+) for temp 350. Process took 5.875540256500244s (0.09792567094167073 minutes)
# Estimated 0.09836275050767154 hours to completion.
# Executing mode 76 , irrep M3+ for temp 350
# Completed mode 76 (irrep M3+) for temp 350. Process took 7.587855339050293s (0.12646425565083821 minutes)
# Estimated 0.09670961776740583 hours to completion.
# Executing mode 79 , irrep M4+ for temp 350
# Completed mode 79 (irrep M4+) for temp 350. Process took 7.389133930206299s (0.12315223217010499 minutes)
# Estimated 0.09504315654324877 hours to completion.
# Executing mode 82 , irrep M5+ for temp 350
# Completed mode 82 (irrep M5+) for temp 350. Process took 5.7771570682525635s (0.09628595113754272 minutes)
# Estimated 0.0932926825080255 hours to completion.
# Executing mode 0 , irrep nomodes for temp 375
# Completed mode 0 (irrep nomodes) for temp 375. Process took 10.365798711776733s (0.17276331186294555 minutes)
# Estimated 0.09176988101756725 hours to completion.
# Executing mode 1 , irrep GM4- for temp 375
# Completed mode 1 (irrep GM4-) for temp 375. Process took 6.047118425369263s (0.10078530708948771 minutes)
# Estimated 0.09002937346840825 hours to completion.
# Executing mode 25 , irrep GM4- for temp 375
# Completed mode 25 (irrep GM4-) for temp 375. Process took 10.054865837097168s (0.1675810972849528 minutes)
# Estimated 0.08847852567434311 hours to completion.
# Executing mode 28 , irrep GM4- for temp 375
# Completed mode 28 (irrep GM4-) for temp 375. Process took 4.8808863162994385s (0.08134810527165731 minutes)
# Estimated 0.08668068396776706 hours to completion.
# Executing mode 4 , irrep R5+ for temp 375
# Completed mode 4 (irrep R5+) for temp 375. Process took 7.190451145172119s (0.11984085241953532 minutes)
# Estimated 0.0849898615439996 hours to completion.
# Executing mode 7 , irrep X1+ for temp 375
# Completed mode 7 (irrep X1+) for temp 375. Process took 9.432150840759277s (0.15720251401265461 minutes)
# Estimated 0.083395660503207 hours to completion.
# Executing mode 43 , irrep X1+ for temp 375
# Completed mode 43 (irrep X1+) for temp 375. Process took 5.096806764602661s (0.08494677941004435 minutes)
# Estimated 0.08160852522834351 hours to completion.
# Executing mode 10 , irrep X5+ for temp 375
# Completed mode 10 (irrep X5+) for temp 375. Process took 10.104798555374146s (0.16841330925623577 minutes)
# Estimated 0.08003363165004224 hours to completion.
# Executing mode 49 , irrep X5+ for temp 375
# Completed mode 49 (irrep X5+) for temp 375. Process took 8.343443155288696s (0.13905738592147826 minutes)
# Estimated 0.07837873502494463 hours to completion.
# Executing mode 55 , irrep X5+ for temp 375
# Completed mode 55 (irrep X5+) for temp 375. Process took 5.777164459228516s (0.09628607432047526 minutes)
# Estimated 0.07661735279250309 hours to completion.
# Executing mode 16 , irrep M2- for temp 375
# Completed mode 16 (irrep M2-) for temp 375. Process took 7.1869165897369385s (0.11978194316228231 minutes)
# Estimated 0.07491165865959887 hours to completion.
# Executing mode 88 , irrep M2- for temp 375
# Completed mode 88 (irrep M2-) for temp 375. Process took 6.767247676849365s (0.11278746128082276 minutes)
# Estimated 0.07318823805261712 hours to completion.
# Executing mode 19 , irrep M5- for temp 375
# Completed mode 19 (irrep M5-) for temp 375. Process took 7.718661546707153s (0.1286443591117859 minutes)
# Estimated 0.07149876198119161 hours to completion.
# Executing mode 91 , irrep M5- for temp 375
# Completed mode 91 (irrep M5-) for temp 375. Process took 5.7353222370147705s (0.09558870395024617 minutes)
# Estimated 0.0697355036055799 hours to completion.
# Executing mode 31 , irrep GM5- for temp 375
# Completed mode 31 (irrep GM5-) for temp 375. Process took 5.516871213912964s (0.09194785356521606 minutes)
# Estimated 0.06796575059493383 hours to completion.
# Executing mode 34 , irrep R2- for temp 375
# Completed mode 34 (irrep R2-) for temp 375. Process took 8.931864261627197s (0.14886440436045328 minutes)
# Estimated 0.06631268041625614 hours to completion.
# Executing mode 35 , irrep R3- for temp 375
# Completed mode 35 (irrep R3-) for temp 375. Process took 9.736121416091919s (0.16226869026819865 minutes)
# Estimated 0.06468066109698964 hours to completion.
# Executing mode 37 , irrep R4- for temp 375
# Completed mode 37 (irrep R4-) for temp 375. Process took 5.139755725860596s (0.08566259543100993 minutes)
# Estimated 0.06289591614405314 hours to completion.
# Executing mode 40 , irrep R5- for temp 375
# Completed mode 40 (irrep R5-) for temp 375. Process took 5.085215330123901s (0.08475358883539835 minutes)
# Estimated 0.06111175288798605 hours to completion.
# Executing mode 46 , irrep X2+ for temp 375
# Completed mode 46 (irrep X2+) for temp 375. Process took 4.862862586975098s (0.0810477097829183 minutes)
# Estimated 0.05932330953335286 hours to completion.
# Executing mode 61 , irrep X3- for temp 375
# Completed mode 61 (irrep X3-) for temp 375. Process took 8.894574642181396s (0.14824291070302328 minutes)
# Estimated 0.057653836797868174 hours to completion.
# Executing mode 64 , irrep X5- for temp 375
# Completed mode 64 (irrep X5-) for temp 375. Process took 5.128080368041992s (0.0854680061340332 minutes)
# Estimated 0.055874387780285514 hours to completion.
# Executing mode 70 , irrep M1+ for temp 375
# Completed mode 70 (irrep M1+) for temp 375. Process took 5.898927688598633s (0.09831546147664388 minutes)
# Estimated 0.05411790068902904 hours to completion.
# Executing mode 73 , irrep M2+ for temp 375
# Completed mode 73 (irrep M2+) for temp 375. Process took 4.910693168640137s (0.08184488614400227 minutes)
# Estimated 0.05233649305094068 hours to completion.
# Executing mode 76 , irrep M3+ for temp 375
# Completed mode 76 (irrep M3+) for temp 375. Process took 11.44472074508667s (0.1907453457514445 minutes)
# Estimated 0.05072114092387193 hours to completion.
# Executing mode 79 , irrep M4+ for temp 375
# Completed mode 79 (irrep M4+) for temp 375. Process took 10.47927188873291s (0.17465453147888182 minutes)
# Estimated 0.04907285839247466 hours to completion.
# Executing mode 82 , irrep M5+ for temp 375
# Completed mode 82 (irrep M5+) for temp 375. Process took 5.930583238601685s (0.09884305397669474 minutes)
# Estimated 0.04731148815265409 hours to completion.
# Executing mode 0 , irrep nomodes for temp 400
# Completed mode 0 (irrep nomodes) for temp 400. Process took 10.659536838531494s (0.17765894730885823 minutes)
# Estimated 0.04565590722295973 hours to completion.
# Executing mode 1 , irrep GM4- for temp 400
# Completed mode 1 (irrep GM4-) for temp 400. Process took 9.409918546676636s (0.15683197577794392 minutes)
# Estimated 0.04396569835505846 hours to completion.
# Executing mode 25 , irrep GM4- for temp 400
# Completed mode 25 (irrep GM4-) for temp 400. Process took 10.008947849273682s (0.16681579748789468 minutes)
# Estimated 0.04228205283239833 hours to completion.
# Executing mode 28 , irrep GM4- for temp 400
# Completed mode 28 (irrep GM4-) for temp 400. Process took 4.91091775894165s (0.08184862931569417 minutes)
# Estimated 0.04049241955566212 hours to completion.
# Executing mode 4 , irrep R5+ for temp 400
# Completed mode 4 (irrep R5+) for temp 400. Process took 6.786418676376343s (0.11310697793960571 minutes)
# Estimated 0.03874020990629689 hours to completion.
# Executing mode 7 , irrep X1+ for temp 400
# Completed mode 7 (irrep X1+) for temp 400. Process took 9.472874402999878s (0.15788124004999796 minutes)
# Estimated 0.037034682615838865 hours to completion.
# Executing mode 43 , irrep X1+ for temp 400
# Completed mode 43 (irrep X1+) for temp 400. Process took 5.013131380081177s (0.08355218966801961 minutes)
# Estimated 0.03524870818475222 hours to completion.
# Executing mode 10 , irrep X5+ for temp 400
# Completed mode 10 (irrep X5+) for temp 400. Process took 10.243218660354614s (0.17072031100591023 minutes)
# Estimated 0.03354824614612613 hours to completion.
# Executing mode 49 , irrep X5+ for temp 400
# Completed mode 49 (irrep X5+) for temp 400. Process took 8.774777173995972s (0.1462462862332662 minutes)
# Estimated 0.03181885930152985 hours to completion.
# Executing mode 55 , irrep X5+ for temp 400
# Completed mode 55 (irrep X5+) for temp 400. Process took 4.966130018234253s (0.08276883363723755 minutes)
# Estimated 0.030031384490603854 hours to completion.
# Executing mode 16 , irrep M2- for temp 400
# Completed mode 16 (irrep M2-) for temp 400. Process took 8.50005841255188s (0.141667640209198 minutes)
# Estimated 0.028293230088393684 hours to completion.
# Executing mode 88 , irrep M2- for temp 400
# Completed mode 88 (irrep M2-) for temp 400. Process took 8.475632905960083s (0.14126054843266805 minutes)
# Estimated 0.026551064618286633 hours to completion.
# Executing mode 19 , irrep M5- for temp 400
# Completed mode 19 (irrep M5-) for temp 400. Process took 6.848795413970947s (0.11414659023284912 minutes)
# Estimated 0.024786492785407576 hours to completion.
# Executing mode 91 , irrep M5- for temp 400
# Completed mode 91 (irrep M5-) for temp 400. Process took 4.743677616119385s (0.07906129360198974 minutes)
# Estimated 0.02299861457103338 hours to completion.
# Executing mode 31 , irrep GM5- for temp 400
# Completed mode 31 (irrep GM5-) for temp 400. Process took 4.263641595840454s (0.07106069326400757 minutes)
# Estimated 0.021208790220693854 hours to completion.
# Executing mode 34 , irrep R2- for temp 400
# Completed mode 34 (irrep R2-) for temp 400. Process took 8.504552364349365s (0.14174253940582277 minutes)
# Estimated 0.019460640274426518 hours to completion.
# Executing mode 35 , irrep R3- for temp 400
# Completed mode 35 (irrep R3-) for temp 400. Process took 9.107770919799805s (0.15179618199666342 minutes)
# Estimated 0.017713801635131265 hours to completion.
# Executing mode 37 , irrep R4- for temp 400
# Completed mode 37 (irrep R4-) for temp 400. Process took 4.928655624389648s (0.08214426040649414 minutes)
# Estimated 0.01593183438854608 hours to completion.
# Executing mode 40 , irrep R5- for temp 400
# Completed mode 40 (irrep R5-) for temp 400. Process took 4.975457668304443s (0.08292429447174073 minutes)
# Estimated 0.01415257792044968 hours to completion.
# Executing mode 46 , irrep X2+ for temp 400
# Completed mode 46 (irrep X2+) for temp 400. Process took 4.533131122589111s (0.07555218537648518 minutes)
# Estimated 0.012373130436052955 hours to completion.
# Executing mode 61 , irrep X3- for temp 400
# Completed mode 61 (irrep X3-) for temp 400. Process took 7.829943895339966s (0.13049906492233276 minutes)
# Estimated 0.010612625492943659 hours to completion.
# Executing mode 64 , irrep X5- for temp 400
# Completed mode 64 (irrep X5-) for temp 400. Process took 5.392201662063599s (0.08987002770105998 minutes)
# Estimated 0.008839939301145636 hours to completion.
# Executing mode 70 , irrep M1+ for temp 400
# Completed mode 70 (irrep M1+) for temp 400. Process took 4.680745840072632s (0.07801243066787719 minutes)
# Estimated 0.007066559156392806 hours to completion.
# Executing mode 73 , irrep M2+ for temp 400
# Completed mode 73 (irrep M2+) for temp 400. Process took 4.828178882598877s (0.08046964804331462 minutes)
# Estimated 0.005296251444981015 hours to completion.
# Executing mode 76 , irrep M3+ for temp 400
# Completed mode 76 (irrep M3+) for temp 400. Process took 8.561795949935913s (0.14269659916559854 minutes)
# Estimated 0.0035343463855046294 hours to completion.
# Executing mode 79 , irrep M4+ for temp 400
# Completed mode 79 (irrep M4+) for temp 400. Process took 9.58732271194458s (0.159788711865743 minutes)
# Estimated 0.001769733112766629 hours to completion.
# Executing mode 82 , irrep M5+ for temp 400
# Completed mode 82 (irrep M5+) for temp 400. Process took 4.765217542648315s (0.07942029237747192 minutes)
# Estimated 0.0 hours to completion.

# %% [markdown]
# Notice this is a lot quicker than the grouped mode run! It is probably best done prior to executing a grouped mode run overnight.
#
# Creating the HDF5 file and cleaning up also require slightly different functions. This is due to the HDF5 file having an extra level of depth (i.e. it has datasets at irrep/mode/prm vs irrep/prm for grouped mode). These also have the unique_modes argument - they won't work if this is different to what is specified for the execute_single function. Like the execute_single function, this is default set to True.

# %%
struc.create_hdf5_single(temps)

struc.cleanup_single()
# Out:
# Creating zip file...
# ...Zip file written.
# Deleting .txt files...
# ...Clean up complete.

# %% [markdown]
# This is the end of this tutorial - move on to SingleMode_ScF3_analysis for analysis of the data generated here.
